# %% [markdown]
# 1. What is a parameter?
#
#
# ans- A parameter is a value that the model learns from the data during training to make predictions (e.g., weights in linear regression).
#
# 2. What is correlation?
#
# ans- Correlation is a statistical measure that indicates how two variables move in relation to each other.
#
# 3. What does negative correlation mean?
#
# ans- Negative correlation means that as one variable increases, the other decreases (and vice versa).
#
# 4. Define Machine Learning. What are the main components in Machine Learning?
#
# ans-Machine Learning is a field of AI where systems learn from data to make predictions or decisions without being explicitly programmed.
#     Main components:Data , Model, Loss function, Optimizer, Evaluation metric.
#
#
# 5. How does loss value help in determining whether the model is good or not?
#
# ans- A low loss value indicates the model is making accurate predictions; a high loss means it's performing poorly.
#
# 6. What are continuous and categorical variables?
#
# ans-1.Continuous variables can take any numeric value (e.g., height, weight).
#     2.Categorical variables represent discrete categories (e.g., gender, color).
#
# 7. How do we handle categorical variables in Machine Learning? What are the common techniques?
#
# ans-Common techniques:
#     1.Label Encoding (assigning numbers to categories)
#     2.One-Hot Encoding (creating binary columns for each category)
#
# 8. What do you mean by training and testing a dataset?
#
# ans- 1.Training a dataset refers to the process of using a portion of the data (called the training set) to teach the machine learning model. During this phase, the model learns patterns and relationships between input features and their corresponding output labels by minimizing a loss function through iterative optimization.
#
#     2.Testing a dataset involves evaluating the performance of the trained model on a separate, unseen portion of the data (called the testing set). This helps to assess how well the model generalizes to new data and provides an estimate of its real-world performance.
#
#
# 9. What is sklearn.preprocessing?
#
# ans- It’s a module in scikit-learn that provides functions for data preprocessing like scaling, encoding, normalization, etc.
#
# 10. What is a Test set?
#
# ans-A test set is a portion of the dataset used after training to evaluate model performance.
#
# 11. How do we split data for model fitting (training and testing) in Python?
#
# ans-In Python, data can be split into training and testing sets using the train_test_split() function from the sklearn.model_selection module. This function randomly divides the dataset into specified proportions for training and testing.
#
# from sklearn.model_selection import train_test_split
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
#
# 12. How do you approach a Machine Learning problem?
#
# ans- Steps:
#     1.Understand the problem
#     2.Collect and clean the data
#     3.Explore the data (EDA)
#     4.Preprocess and transform the data
#     5.Select and train models
#     6.Evaluate models
#     7.Tune hyperparameters
#     8.Deploy the model
#
# 13. Why do we have to perform EDA before fitting a model to the data?
#
# ans- EDA (Exploratory Data Analysis) helps understand the data distribution, detect outliers, check for missing values, and identify relationships between variables.
#
#
#
# 14. How can you find correlation between variables in Python?
#
# ans-In Python, the correlation between variables can be found using the .corr() method from the pandas library. This method computes the Pearson correlation coefficient by default, which measures the linear relationship between numerical variables.
#
# import pandas as pd
# df.corr()
#
# 15. What is causation? Explain difference between correlation and causation with an example.
#
# ans-Causation means one variable directly affects another.
#
# Correlation is just a relationship, not necessarily cause-effect.
# Example: Ice cream sales and drowning are correlated (both rise in summer), but ice cream doesn't cause drowning.
#
# 16. What is an Optimizer? What are different types of optimizers? Explain each with an example.
#
# ans-An optimizer updates the model’s parameters to minimize the loss function.
#     Types:
#     1.SGD (Stochastic Gradient Descent): updates weights with each data point.
#     2.Adam: adaptive learning rate optimizer, efficient and popular.
#     3.RMSprop: adjusts learning rate based on recent gradient magnitudes.
#
# 17. What is sklearn.linear_model?
#
# ans-It is a module in scikit-learn containing linear models like LinearRegression, LogisticRegression, etc.
#
# 18. What does model.fit() do? What arguments must be given?
#
# ans- model.fit(X, y) trains the model using features X and target y.
#
# 19. What does model.predict() do? What arguments must be given?
#
# ans-model.predict(X) returns predictions for the input features X using the trained model.
#
#
# 20. What is feature scaling? How does it help in Machine Learning?
#
# ans-Feature scaling transforms features to the same scale. It helps algorithms like KNN, SVM, and gradient descent perform better.
#
# 21. Explain data encoding?
#
# ans-Data encoding is converting categorical variables into numerical format for machine learning models to process.
# Common methods:
# 1.Label Encoding
# 2.One-Hot Encoding

# %% [markdown]
#     NOTE- THERE ARE SOME REPEATED QUESTIONS PLEASE CROSS CHECK THE PDF

# %%
#PRACTICAL IMPLEAMENTATION OF QUESTION 14
#14. How can you find correlation between variables in Python?

import pandas as pd  

df = pd.DataFrame({
    'A': [1, 2, 3, 4],
    'B': [2, 4, 6, 8]
})

correlation_matrix = df.corr()
print(correlation_matrix)
# Out:
#      A    B
# A  1.0  1.0
# B  1.0  1.0

# %%
#PRACTICAL IMPLEAMENTATION OF QUESTION 11
#11. How do we split data for model fitting (training and testing) in Python?


from sklearn.model_selection import train_test_split

# Sample data
X = [[1], [2], [3], [4], [5]]
y = [1, 2, 3, 4, 5]

# Split data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

print("Training data:", X_train)
print("Testing data:", X_test)
# Out:
# Training data: [[3], [2], [4], [5]]
# Testing data: [[1]]
